# %%
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xg

# %%
data = pd.read_csv('long.csv')
data_balance = data["Price"]
data_profit = data["Order"]
data.head()
# Out:
#    #              Time Type  Order  Size     Price     S / L     T / P  \
# 0  1  2023.04.24 08:00  buy      1  0.04  33701.77  33634.37  33748.95
# 1  2  2023.04.24 12:22  t/p      1  0.04  33748.95  33634.37  33748.95
# 2  3  2023.04.24 12:46  buy      2  0.04  33751.70  33684.20  33798.95
# 3  4  2023.04.24 14:32  t/p      2  0.04  33798.95  33684.20  33798.95
# 4  5  2023.04.24 14:45  buy      3  0.04  33786.33  33718.76  33833.63
#
#    Profit   Balance
# 0    0.00  10000.00
# 1  188.52  10188.52
# 2  188.52  10188.52
# 3  188.80  10377.32
# 4  188.80  10377.32

# %%
bdfbal = pd.DataFrame(data,columns=['Balance'])
bdfbal.plot()
# Out:
# <Axes: >

# %%
bdfprof = pd.DataFrame(data,columns=['Profit'])
bdfprof.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
bdfbal = pd.DataFrame(data,columns=['Price'])
bdfbal.plot()
# Out:
# <Axes: >

# %%
features = ["T/P", "S/L"]
target = ["Price"]
